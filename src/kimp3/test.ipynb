# %%
import lastfm
from rich.pretty import pretty_repr
from rich.pretty import pprint
from config import cfg
from models import AudioTags
from song import AudioFile
from songdir import SongDir
# Out:
# 22:34:02 INFO     Parsing args                                                                         ]8;id=97489;file:///home/kimifish/pyprojects/kimp3/src/kimp3/config.py\config.py]8;;\:]8;id=445873;file:///home/kimifish/pyprojects/kimp3/src/kimp3/config.py#83\83]8;;\
#          DEBUG    Compiling regex patterns                                                            ]8;id=994458;file:///home/kimifish/pyprojects/kimp3/src/kimp3/config.py\config.py]8;;\:]8;id=103775;file:///home/kimifish/pyprojects/kimp3/src/kimp3/config.py#118\118]8;;\
# 📄 Configuration ┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄┄
# ├── decode: False
# ├── dry_run: False
# ├── interactive: True
# ├── scan
# │   ├── dir_list
# │   │   └── 0: /home/kimifish/Downloads/Laserdance/Albums/1987 Future Generation
# │   ├── skip_dirs
# │   │   ├── 0: .unwanted
# │   │   └── 1: .AppleDouble
# │   ├── delete_empty_dirs: True
# │   ├── skip_files
# │   │   └── 0: .some_useless_file
# │   ├── valid_extensions
# │   │   ├── 0: .mp3
# │   │   └── 1: .flac
# │   ├── move_or_copy: copy
# │   └── common_files
# │       ├── 0: AlbumArtSmall.jpg
# │       ├── 1: Folder.jpg
# │       ├── 2: Thumbs.db
# │       ├── 3: front.jpg
# │       ├── 4: Cover.jpg
# │       └── 5: front.jpeg
# ├── collection
# │   ├── directory: /home/kimifish/Music
# │   ├── compilation_test: True
# │   └── compilation_coef: 0.5
# ├── paths
# │   ├── patterns
# │   │   ├── album: %album_artist/%year - %album_title (CD%disc_num)/%track_num. %song_title.mp3
# │   │   ├── compilation: _Сборники/%album_title (CD%disc_num)/%track_num. %song_artist - %song_title.mp3
# │   │   └── genre: _Жанры/%genre/%year. %song_artist - %song_title.mp3
# │   ├── cut_empty_tags: True
# │   ├── cut_year_only_folders: True
# │   ├── bad_artists
# │   │   ├── 0: unknown artist
# │   │   ├── 1: unknown
# │   │   ├── 2: неизвестный исполнитель
# │   │   └── 3: неизвестный артист
# │   └── the_the: remove
# ├── lastfm
# │   ├── api_key: a35c3aff92e37e15166bdd4dfa21ac0b
# │   ├── api_secret: 0a3e43cace94055b76501bd04ecf0f6b
# │   ├── discogs_token: zTPNviIbXFyGsxkTgTMqYYQjEkVkUrbecFuXLigS
# │   ├── username: kimifish
# │   ├── password_hash: 3da005c0951fa144c26b14869de1ce91
# │   ├── autocorrection: True
# │   ├── genres
# │   │   ├── 0: acoustic
# │   │   ├── 1: acoustic rock
# │   │   ├── 2: afrobeat
# │   │   ├── 3: afropop
# │   │   ├── 4: alternative
# │   │   ├── 5: alternative metal
# │   │   ├── 6: alternative rock
# │   │   ├── 7: ambient
# │   │   ├── 8: americana
# │   │   ├── 9: anarcho-punk
# │   │   ├── 10: art pop
# │   │   ├── 11: art rock
# │   │   ├── 12: avant-garde
# │   │   ├── 13: baroque
# │   │   ├── 14: bebop
# │   │   ├── 15: big band
# │   │   ├── 16: black metal
# │   │   ├── 17: bluegrass
# │   │   ├── 18: blues
# │   │   ├── 19: blues rock
# │   │   ├── 20: bossa nova
# │   │   ├── 21: breakbeat
# │   │   ├── 22: britpop
# │   │   ├── 23: cajun
# │   │   ├── 24: calypso
# │   │   ├── 25: celtic
# │   │   ├── 26: chamber music
# │   │   ├── 27: chanson
# │   │   ├── 28: chillout
# │   │   ├── 29: chiptune
# │   │   ├── 30: christian rock
# │   │   ├── 31: city pop
# │   │   ├── 32: classic rock
# │   │   ├── 33: classical
# │   │   ├── 34: cloud rap
# │   │   ├── 35: conscious rap
# │   │   ├── 36: contemporary classical
# │   │   ├── 37: country
# │   │   ├── 38: country pop
# │   │   ├── 39: country rock
# │   │   ├── 40: crunk
# │   │   ├── 41: crust punk
# │   │   ├── 42: cumbia
# │   │   ├── 43: dance
# │   │   ├── 44: dancehall
# │   │   ├── 45: dark ambient
# │   │   ├── 46: dark wave
# │   │   ├── 47: death metal
# │   │   ├── 48: deathcore
# │   │   ├── 49: deep house
# │   │   ├── 50: delta blues
# │   │   ├── 51: disco
# │   │   ├── 52: dixieland
# │   │   ├── 53: doom metal
# │   │   ├── 54: downtempo
# │   │   ├── 55: dream pop
# │   │   ├── 56: drill
# │   │   ├── 57: drone
# │   │   ├── 58: drum and bass
# │   │   ├── 59: dub
# │   │   ├── 60: dubstep
# │   │   ├── 61: edm
# │   │   ├── 62: electro
# │   │   ├── 63: electro swing
# │   │   ├── 64: electronic
# │   │   ├── 65: electronica
# │   │   ├── 66: emo
# │   │   ├── 67: emo rap
# │   │   ├── 68: ethereal
# │   │   ├── 69: eurodance
# │   │   ├── 70: experimental
# │   │   ├── 71: fado
# │   │   ├── 72: flamenco
# │   │   ├── 73: folk
# │   │   ├── 74: folk metal
# │   │   ├── 75: folk pop
# │   │   ├── 76: folk punk
# │   │   ├── 77: folk rock
# │   │   ├── 78: free jazz
# │   │   ├── 79: funk
# │   │   ├── 80: funk rock
# │   │   ├── 81: fusion jazz
# │   │   ├── 82: future bass
# │   │   ├── 83: g-funk
# │   │   ├── 84: gabber
# │   │   ├── 85: garage
# │   │   ├── 86: garage rock
# │   │   ├── 87: glam metal
# │   │   ├── 88: glam rock
# │   │   ├── 89: glitch
# │   │   ├── 90: goa trance
# │   │   ├── 91: gospel
# │   │   ├── 92: gothic metal
# │   │   ├── 93: gothic rock
# │   │   ├── 94: grime
# │   │   ├── 95: grindcore
# │   │   ├── 96: groove metal
# │   │   ├── 97: grunge
# │   │   ├── 98: hard rock
# │   │   ├── 99: hardcore
# │   │   ├── 100: hardcore punk
# │   │   ├── 101: hardstyle
# │   │   ├── 102: heavy metal
# │   │   ├── 103: hi-nrg
# │   │   ├── 104: highlife
# │   │   ├── 105: hip hop
# │   │   ├── 106: horrorcore
# │   │   ├── 107: house
# │   │   ├── 108: hyperpop
# │   │   ├── 109: idm
# │   │   ├── 110: indie
# │   │   ├── 111: indie folk
# │   │   ├── 112: indie pop
# │   │   ├── 113: indie rock
# │   │   ├── 114: industrial
# │   │   ├── 115: industrial metal
# │   │   ├── 116: italo-disco
# │   │   ├── 117: j-pop
# │   │   ├── 118: j-rock
# │   │   ├── 119: jam band
# │   │   ├── 120: jazz
# │   │   ├── 121: jazz fusion
# │   │   ├── 122: jazz rap
# │   │   ├── 123: jazz rock
# │   │   ├── 124: jug band
# │   │   ├── 125: k-pop
# │   │   ├── 126: krautrock
# │   │   ├── 127: latin
# │   │   ├── 128: latin jazz
# │   │   ├── 129: latin pop
# │   │   ├── 130: liquid funk
# │   │   ├── 131: lo-fi
# │   │   ├── 132: lounge
# │   │   ├── 133: madchester
# │   │   ├── 134: makossa
# │   │   ├── 135: math rock
# │   │   ├── 136: medieval
# │   │   ├── 137: melodic death metal
# │   │   ├── 138: merengue
# │   │   ├── 139: metal
# │   │   ├── 140: metalcore
# │   │   ├── 141: minimal
# │   │   ├── 142: moombahton
# │   │   ├── 143: motown
# │   │   ├── 144: neo-classical
# │   │   ├── 145: neo-soul
# │   │   ├── 146: neotraditional country
# │   │   ├── 147: new age
# │   │   ├── 148: new jack swing
# │   │   ├── 149: new wave
# │   │   ├── 150: no wave
# │   │   ├── 151: noise
# │   │   ├── 152: noise rock
# │   │   ├── 153: northern soul
# │   │   ├── 154: nu jazz
# │   │   ├── 155: nu metal
# │   │   ├── 156: oi!
# │   │   ├── 157: opera
# │   │   ├── 158: orchestral
# │   │   ├── 159: outlaw country
# │   │   ├── 160: p-funk
# │   │   ├── 161: philly soul
# │   │   ├── 162: phonk
# │   │   ├── 163: polka
# │   │   ├── 164: pop
# │   │   ├── 165: pop punk
# │   │   ├── 166: pop rock
# │   │   ├── 167: post-hardcore
# │   │   ├── 168: post-metal
# │   │   ├── 169: post-punk
# │   │   ├── 170: post-rock
# │   │   ├── 171: power metal
# │   │   ├── 172: power pop
# │   │   ├── 173: progressive house
# │   │   ├── 174: progressive metal
# │   │   ├── 175: progressive rock
# │   │   ├── 176: psychedelic
# │   │   ├── 177: psychedelic rock
# │   │   ├── 178: psychobilly
# │   │   ├── 179: punk
# │   │   ├── 180: punk blues
# │   │   ├── 181: punk rock
# │   │   ├── 182: qawwali
# │   │   ├── 183: queercore
# │   │   ├── 184: r&b
# │   │   ├── 185: ragga
# │   │   ├── 186: raga rock
# │   │   ├── 187: ragtime
# │   │   ├── 188: rap
# │   │   ├── 189: rap metal
# │   │   ├── 190: rap rock
# │   │   ├── 191: reggae
# │   │   ├── 192: reggaeton
# │   │   ├── 193: renaissance
# │   │   ├── 194: retrowave
# │   │   ├── 195: riot grrrl
# │   │   ├── 196: rock
# │   │   ├── 197: rock and roll
# │   │   ├── 198: rockabilly
# │   │   ├── 199: roots reggae
# │   │   ├── 200: salsa
# │   │   ├── 201: samba
# │   │   ├── 202: screamo
# │   │   ├── 203: shoegaze
# │   │   ├── 204: singer-songwriter
# │   │   ├── 205: ska
# │   │   ├── 206: ska punk
# │   │   ├── 207: skiffle
# │   │   ├── 208: smooth jazz
# │   │   ├── 209: soca
# │   │   ├── 210: soft rock
# │   │   ├── 211: soul
# │   │   ├── 212: southern gothic
# │   │   ├── 213: southern rock
# │   │   ├── 214: space rock
# │   │   ├── 215: space synth
# │   │   ├── 216: speed metal
# │   │   ├── 217: spoken word
# │   │   ├── 218: stoner rock
# │   │   ├── 219: surf rock
# │   │   ├── 220: swing
# │   │   ├── 221: symphonic metal
# │   │   ├── 222: synth pop
# │   │   ├── 223: synthwave
# │   │   ├── 224: tango
# │   │   ├── 225: tech house
# │   │   ├── 226: techno
# │   │   ├── 227: teen pop
# │   │   ├── 228: thrash metal
# │   │   ├── 229: trance
# │   │   ├── 230: trap
# │   │   ├── 231: tribal house
# │   │   ├── 232: trip hop
# │   │   ├── 233: tropicália
# │   │   ├── 234: turntablism
# │   │   ├── 235: uk garage
# │   │   ├── 236: vaporwave
# │   │   ├── 237: viking metal
# │   │   ├── 238: vocal jazz
# │   │   ├── 239: west coast hip hop
# │   │   ├── 240: western swing
# │   │   ├── 241: world music
# │   │   ├── 242: zouk
# │   │   └── 243: zydeco
# │   ├── banned_tags: song, hit, new, la la la, popular, increasingly popular, eurovision, gold, gay, albums i own,
# │   │   loved, awesome, good songs, vinyl, deep purple, seen live, alternative, niravana - nevermind, kurt cobain,
# │   │   adriano, top100albumsbyme, ddt,
# │   ├── banned_tags_patterns
# │   │   ├── 0: re.compile('\\d+')
# │   │   ├── 1: re.compile('best')
# │   │   ├── 2: re.compile('best of.*')
# │   │   ├── 3: re.compile('discovered in.*')
# │   │   ├── 4: re.compile('top [\\d+|artists|cd]')
# │   │   ├── 5: re.compile('\\d+ of \\d+ .*')
# │   │   ├── 6: re.compile('.*streamable.*')
# │   │   ├── 7: re.compile('favou?rite.*')
# │   │   ├── 8: re.compile('.* before you die')
# │   │   └── 9: re.compile('.*seixas')
# │   ├── banned_artists_from_tags
# │   │   ├── rock
# │   │   │   └── 0: ABBA
# │   │   └── japanese
# │   │       └── 0: ДДТ
# │   ├── similar_tags
# │   │   ├── 0: ['latin', 'latin music']
# │   │   └── 1: ['house', 'house music']
# │   └── similar_tags_patterns
# │       ├── 0: ['50s', re.compile("(?:50|50\\'s|fifties|1950\\'s?)")]
# │       ├── 1: ['60s', re.compile("(?:60|60\\'s|sixties|1960\\'s?)")]
# │       ├── 2: ['70s', re.compile("(?:70|70\\'s|seventies|1970\\'s?)")]
# │       ├── 3: ['80s', re.compile("(?:80|80\\'s|eighties|1980\\'s?)")]
# │       ├── 4: ['90s', re.compile("(?:90|90\\'s|nineties|1990\\'s?)")]
# │       ├── 5: ['00s', re.compile("(?:00\\'s|two thousands|2000s|2000-2009|aughts|noughties)")]
# │       ├── 6: ['dark wave', re.compile('dark[-\\s/]?wave')]
# │       ├── 7: ['dark synth', re.compile('dark[-\\s/]?synth')]
# │       ├── 8: ['punk rock', re.compile('punk[-\\s/]?rock')]
# │       ├── 9: ['female vocalist', re.compile('female voc.*')]
# │       ├── 10: ['rock', re.compile('rock\\smusic')]
# │       ├── 11: ['alternative rock', re.compile('(?:alt\\srock|alternative-rock)')]
# │       ├── 12: ['punk rock', re.compile('punk[-\\s/]?rock')]
# │       ├── 13: ['pop rock', re.compile('(?:pop[-\\s/]?rock|rockpop|poprock)')]
# │       ├── 14: ['synth pop', re.compile('(?:synthpop|synth-pop|synth[-\\s]?dance)')]
# │       ├── 15: ['electronic', re.compile('electronica')]
# │       ├── 16: ['techno', re.compile('tehno')]
# │       ├── 17: ['smooth jazz', re.compile('smooth-jazz')]
# │       ├── 18: ['classical', re.compile('classical music')]
# │       ├── 19: ['rap', re.compile('rap music')]
# │       ├── 20: ['soul', re.compile('soul music')]
# │       ├── 21: ['reggae', re.compile('reggae music')]
# │       ├── 22: ['latin', re.compile('latin music')]
# │       ├── 23: ['house', re.compile('house music')]
# │       ├── 24: ['trance', re.compile('trance music')]
# │       ├── 25: ['dubstep', re.compile('dubstep music')]
# │       ├── 26: ['jazz', re.compile('jazz music')]
# │       ├── 27: ['blues', re.compile('blues music')]
# │       ├── 28: ['pop', re.compile('pop music')]
# │       ├── 29: ['punk', re.compile('punk music')]
# │       ├── 30: ['male vocalist', re.compile('male\\s(?:vocals|vocalists?)')]
# │       ├── 31: ['instrumental', re.compile('(?:no\\svocals|instrumental\\smusic)')]
# │       ├── 32: ['female vocalist', re.compile('female\\svoc.*')]
# │       ├── 33: ['american', re.compile('(?:usa|united states|american artists?)')]
# │       ├── 34: ['british', re.compile('(?:uk|united kingdom|british artists?)')]
# │       ├── 35: ['french', re.compile('(?:france|french artists?)')]
# │       ├── 36: ['german', re.compile('(?:germany|german artists?)')]
# │       ├── 37: ['italian', re.compile('(?:italy|italian artists?)')]
# │       ├── 38: ['japanese', re.compile('(?:japan|japanese artists?)')]
# │       ├── 39: ['korean', re.compile('(?:korea|korean artists?)')]
# │       ├── 40: ['russian', re.compile('(?:russia|russian artists?)')]
# │       ├── 41: ['synthwave', re.compile('(?:synth[-\\s]?wave|synth wave)')]
# │       ├── 42: ['space synth', re.compile('(?:space-synth|spacesynth|spacewave|space wave)')]
# │       ├── 43: ['dance', re.compile('(?:dance pop|dance-pop)')]
# │       ├── 44: ['disco', re.compile('(?:euro disco|euro-disco)')]
# │       ├── 45: ['electroswing', re.compile('(?:electro swing|electro-swing)')]
# │       ├── 46: ['nu jazz', re.compile('nu-jazz')]
# │       ├── 47: ['folk rock', re.compile('folk[-\\s]?rock')]
# │       ├── 48: ['hard rock', re.compile('hard[-\\s]?rock')]
# │       ├── 49: ['progressive rock', re.compile('(?:prog\\srock|progressive-rock)')]
# │       ├── 50: ['garage rock', re.compile('garage[-\\s]?rock')]
# │       ├── 51: ['metal', re.compile('(?:heavy\\smetal|metal\\smusic)')]
# │       ├── 52: ['euro pop', re.compile('(?:europop|euro-pop)')]
# │       ├── 53: ['k-pop', re.compile('kpop')]
# │       ├── 54: ['j-pop', re.compile('jpop')]
# │       ├── 55: ['hip hop', re.compile('(?:hip-hop|hiphop)')]
# │       ├── 56: ['r&b', re.compile('(?:r\\sand\\sb|rhythm\\sand\\sblues|rnb)')]
# │       ├── 57: ['classical', re.compile('classical\\smusic')]
# │       ├── 58: ['country', re.compile('(?:country\\smusic|country\\sand\\swestern)')]
# │       ├── 59: ['folk', re.compile('folc')]
# │       ├── 60: ['live', re.compile('(?:live\\sperformance|concert\\srecording)')]
# │       ├── 61: ['studio', re.compile('studio\\srecording')]
# │       ├── 62: ['remix', re.compile('(?:remixed|remix\\sversion)')]
# │       ├── 63: ['cover', re.compile('(?:cover\\sversion|covered\\sby)')]
# │       ├── 64: ['original', re.compile('original\\sversion')]
# │       ├── 65: ['acoustic', re.compile('(?:unplugged|acoustic\\smusic)')]
# │       └── 66: ['indie', re.compile('(?:indie[-\\s]?rock|indie-rock)')]
# ├── tags
# │   ├── tag_reader: eyed3
# │   └── check_tags: True
# ├── logging
# │   ├── level: DEBUG
# │   └── loggers
# │       ├── suppress
# │       │   ├── 0: httpx
# │       │   ├── 1: httpcore
# │       │   ├── 2: mutagen
# │       │   └── 3: pylast
# │       └── suppress_level: WARNING
# ├── f: /run/user/1000/jupyter/runtime/kernel-v3a6ffe86a05b4ac261a61434db3cc757681a8671e.json
# └── Config file: ['/home/kimifish/.config/kimp3/config.yaml']

# %%
lastfm.init_lastfm()
net = lastfm.network
# Out:
# 22:34:07 INFO     Last.FM login                                                                       ]8;id=568871;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=48772;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#194\194]8;;\

# %%
# s = AudioFile("/home/kimifish/Downloads/Laserdance/Albums/1993 Hypermagic/03 Fire On Ice.mp3")
s = SongDir("/home/kimifish/Downloads/Perturbator/2014 - Dangerous Days")
# pprint(s.tags)
changes = s.check_tags()
# pprint(s.tags)
pprint(changes)

# %%
pprint(lastfm._artist_corrections)
pprint(lastfm._album_corrections)
#pprint(lastfm._artist_albums_cache, max_depth=3)
pprint(lastfm._album_tracks_cache)
pprint(lastfm._artist_tags_cache)
pprint(lastfm._album_tags_cache)

# %%
at = [
    AudioTags(title="dancing queen", artist="abba", album="arrival"),
    AudioTags(title="stain", artist="nervana", album="insecticide"),
    AudioTags(title="angeleyes", artist="abba", album="vulez vous"),
    AudioTags(title="в последную осень", artist="ДДТ", album="актриса весна"),
]
for a in at:
    lft = lastfm.TaggedTrack(a)
# Out:
# 22:34:11 DEBUG    {                                                                                   ]8;id=872955;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=171577;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#351\351]8;;\
#                       '',
#                       'energetic',
#                       'party',
#                       'dance',
#                       'romantic',
#                       'albums i own',
#                       'happy',
#                       'pop',
#                       'oldies',
#                       '80s',
#                       'dance-pop',
#                       'disco',
#                       'pop rock',
#                       'swedish',
#                       '70s',
#                       '1001 albums you must hear before you die',
#                       'sexy',
#                       'female vocalists',
#                       '1970s',
#                       'rock',
#                       'europop',
#                       '1976'
#                   }
#          DEBUG    {                                                                                    ]8;id=325356;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=367230;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#57\57]8;;\
#                       'artist': 'ABBA',
#                       'album': 'Arrival',
#                       'album_artist': 'ABBA',
#                       'title': 'Dancing Queen',
#                       'track': '2/10',
#                       'genre': 'dance, disco, rock, pop rock',
#                       'lastfm_tags': 'energetic, romantic, swedish, happy, female vocalist, party,
#                   euro pop, sexy, oldies'
#                   }
# 22:34:13 DEBUG    {                                                                                   ]8;id=416205;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=828487;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#351\351]8;;\
#                       'punk rock',
#                       'punk',
#                       'alternative rock',
#                       'seattle',
#                       'hard rock',
#                       '',
#                       'albums i own',
#                       'rock',
#                       'american',
#                       'alternative',
#                       'favorites',
#                       'grunge',
#                       '90s'
#                   }
#          DEBUG    {                                                                                    ]8;id=992963;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=182841;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#57\57]8;;\
#                       'artist': 'Nirvana',
#                       'album': 'Incesticide',
#                       'album_artist': 'Nirvana',
#                       'title': 'Stain',
#                       'track': '3/15',
#                       'genre': 'punk rock, punk, alternative rock, hard rock, rock, grunge',
#                       'lastfm_tags': 'seattle, american'
#                   }
# 22:34:15 DEBUG    {                                                                                   ]8;id=495627;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=651420;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#351\351]8;;\
#                       '',
#                       '1979',
#                       'dance',
#                       'euro disco',
#                       'euro-pop',
#                       'albums i own',
#                       'happy',
#                       'sweden',
#                       'pop',
#                       'oldies',
#                       '80s',
#                       'dance-pop',
#                       'disco',
#                       'swedish',
#                       '70s',
#                       'female vocalists',
#                       '1970s',
#                       'rock',
#                       'europop'
#                   }
#          DEBUG    {                                                                                    ]8;id=590255;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=548109;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#57\57]8;;\
#                       'artist': 'ABBA',
#                       'album': 'Voulez-Vous',
#                       'album_artist': 'ABBA',
#                       'title': 'Angeleyes',
#                       'track': '4/10',
#                       'genre': 'dance, disco, rock',
#                       'lastfm_tags': 'swedish, happy, sweden, female vocalist, euro pop, oldies'
#                   }
# 22:34:17 DEBUG    {                                                                                   ]8;id=569373;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=89519;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#351\351]8;;\
#                       '',
#                       'russia',
#                       '1992',
#                       '2000',
#                       'favorite albums',
#                       'albums i own',
#                       'rock',
#                       'fully streamable albums',
#                       'ddt',
#                       'russian rock',
#                       '90s',
#                       'japanese',
#                       'adriano',
#                       'favourite albums',
#                       'russian',
#                       '1990s'
#                   }
#          DEBUG    {                                                                                    ]8;id=61770;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py\lastfm.py]8;;\:]8;id=747428;file:///home/kimifish/pyprojects/kimp3/src/kimp3/lastfm.py#57\57]8;;\
#                       'artist': 'ДДТ',
#                       'album': 'Актриса Весна',
#                       'album_artist': 'ДДТ',
#                       'title': 'В последную осень',
#                       'genre': 'rock',
#                       'lastfm_tags': 'japanese, russian'
#                   }

# %%
'japanese' in cfg.lastfm.banned_artists_from_tags.__dict__
'ддт' in cfg.lastfm.banned_artists_from_tags.__dict__['japanese']
# Out:
# False
